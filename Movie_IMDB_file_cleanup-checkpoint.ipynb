# %%
import pandas as pd
from string import printable

# %%
df1 = pd.read_csv('title.basics.tsv', sep='\t')
# Out:
# /Users/smita/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2 = pd.read_csv('title.ratings.tsv', sep='\t')

# %%
df = pd.merge(df1, df2, on='tconst')

# %%
df.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     short                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle isAdult startYear endYear  \
# 0                                   Carmencita       0      1894      \N
# ...

# %%
#df3=pd.read_csv('movie.tsv', sep = '\t')

# %%
# Check for null values in each column and remove the null row
print(df.isnull().sum())
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            2
# averageRating     0
# numVotes          0
# dtype: int64

# %%
print(df.isnull().sum().sum()) #Sum of all null values
# Out:
# 2

# %%
df = df.dropna(how='any',axis=0) #Remove all null values

# %%
df['primaryTitle'] = df['primaryTitle'].str.replace('\W', ' ')
# Out:
# <ipython-input-140-ee874a883564>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['primaryTitle'] = df['primaryTitle'].str.replace('\W', ' ')

# %%
df['originalTitle'] = df['originalTitle'].str.replace('\W', ' ')
# Out:
# <ipython-input-141-74f3246ff0a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['originalTitle'] = df['originalTitle'].str.replace('\W', ' ')

# %%
#df3.replace(regex=True, to_replace =['¢','€','£', 'Ã', '¬', 'Ð', '±','½','©','•','¾', '§', '¥', '«', '¤', '–', 'œ', '¡', '”', '|', 'â', '™', 'Â', 'Î', '¿', 'µ', '´', '‡','»', 'Ž', '®', 'º', 'Ï', 'ƒ', '¶', '¹', '┬', 'á', 'Γ', 'Ç', 'Ö'], value='', inplace=True)

# %%
df.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'averageRating',
#        'numVotes'],
#       dtype='object')

# %%
df4 = df[['tconst', 'isAdult','startYear', 'endYear', 'runtimeMinutes', 'genres', 'averageRating','numVotes']]

# %%
df5 = df3[['tconst','primaryTitle', 'originalTitle']]

# %%
df5 = df5.applymap(str) #Convert the dataframe into string

# %%
df5=df5.applymap(lambda y: ''.join(filter(lambda x: x in printable, y))) #Splitting dataframes was necessary as applymap will not work on int datatype

# %%
df5['primaryTitle'] = df5['primaryTitle'].str.replace('\W', '') #Remove printable special characters

# %%
df5['originalTitle'] = df5['originalTitle'].str.replace('\W', '') #Remove printable special characters

# %%
df6 = pd.merge(df4, df5, on='tconst')

# %%
df6.head(26)
# Out:
#        tconst isAdult startYear endYear runtimeMinutes  \
# 0   tt0000001       0      1894      \N              1
# 1   tt0000002       0      1892      \N              5
# 2   tt0000003       0      1892      \N              4
# 3   tt0000004       0      1892      \N             12
# 4   tt0000005       0      1893      \N              1
# 5   tt0000006       0      1894      \N              1
# 6   tt0000007       0      1894      \N              1
# 7   tt0000008       0      1894      \N              1
# 8   tt0000009       0      1894      \N             40
# 9   tt0000010       0      1895      \N              1
# 10  tt0000011       0      1895      \N              1
# 11  tt0000012       0      1896      \N              1
# 12  tt0000013       0      1895      \N              1
# 13  tt0000014       0      1895      \N              1
# 14  tt0000015       0      1894      \N              2
# 15  tt0000016       0      1895      \N              1
# ...

# %%
df6.columns
# Out:
# Index(['tconst', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres',
#        'averageRating', 'numVotes', 'primaryTitle', 'originalTitle'],
#       dtype='object')

# %%
df6.to_csv('movie_cleaned_data.tsv', sep = '\t', index=False)
